# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.8/165.8 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 780.5 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 33.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 2.8 MB/s eta 0:00:00
# ...

# %%
# !pip install optuna
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# !pip install pycaret[tuners]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 MB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 7.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install seaborn scikit-learn

# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
import pycaret
from pycaret.classification import ClassificationExperiment
from pycaret.classification import ClassificationExperiment, tune_model

warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (10, 10)

# %%
# Load dataset
df_bank = pd.read_csv('/content/drive/MyDrive/ITStudy/09_MLDL/bank.csv')

# %%
# 원본 데이터를 미리 저장해둡니다.
df_original = df_bank.copy()

# %%
# PyCaret 설정: 전진 선택법과 함께 피처 선택
s = ClassificationExperiment()

# setup의 결과를 'exp' 변수에 저장 (feature_selection을 True로 설정)
exp = s.setup(df_bank,
              target='deposit',
              session_id=123,
              feature_selection=True,  # 전진 선택법 활성화
              feature_selection_method='classic')  # 전통적인 전진 선택법 사용
# Out:
# [LightGBM] [Info] Number of positive: 3702, number of negative: 4111
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002927 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1003
# [LightGBM] [Info] Number of data points in the train set: 7813, number of used features: 48
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.473826 -> initscore=-0.104793
# [LightGBM] [Info] Start training from score -0.104793
# <style type="text/css">
# #T_baec7_row10_col1, #T_baec7_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_baec7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_baec7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_baec7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
# ...

# %%
best_model = s.compare_models()  # 모델 비교 후 가장 좋은 모델 선택
# Out:
# <style type="text/css">
# #T_7503d th {
#   text-align: left;
# }
# ...

# %% [markdown]
# 우와 전진선택법으로 전처리 했는데 내려가네...?

# %% [markdown]
# 그럼 전처리 하지말고 해야지,,

# %%
# PyCaret 설정: 전진 선택법과 함께 피처 선택
s = ClassificationExperiment()

# setup의 결과를 'exp' 변수에 저장
exp = s.setup(df_bank,
              target='deposit',
              session_id=123,
              feature_selection=False)  # 전진 선택법 비활성화
# Out:
# <style type="text/css">
# #T_ad158_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ad158" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad158_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ad158_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad158_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad158_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ad158_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ad158_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad158_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ad158_row1_col1" class="data row1 col1" >deposit</td>
#     </tr>
#     <tr>
#       <th id="T_ad158_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = s.compare_models()  # 모델 비교 후 가장 좋은 모델 선택
# Out:
# <style type="text/css">
# #T_39b0f th {
#   text-align: left;
# }
# ...

# %%
best_model
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
print(best_model)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
import pandas as pd
import optuna
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# 원본 데이터프레임에서 'deposit' 컬럼 분리
X = df_bank.drop('deposit', axis=1)
y = df_bank['deposit']

# 범주형 변수 인코딩
X_encoded = pd.get_dummies(X, drop_first=True)  # one-hot 인코딩

# 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.3, random_state=123)

# Objective function for Optuna
def objective(trial):
    param = {
        'objective': 'binary', # 목표 함수 설정: 이진 분류 문제
        'metric': 'binary_error',  # 평가 지표: 이진 오류
        'num_leaves': trial.suggest_int('num_leaves', 2, 256),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),
        'n_estimators': trial.suggest_int('n_estimators', 10, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
    }

    model = lgb.LGBMClassifier(**param) # 모델초기화
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    accuracy = accuracy_score(y_test, preds)

    return accuracy

# Optuna optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Best parameters
print(study.best_params)
# Out:
# [I 2024-09-19 12:24:02,828] A new study created in memory with name: no-name-a6b36558-47bc-45ce-8f0b-f72ec108bbaa
# [LightGBM] [Info] Number of positive: 3687, number of negative: 4126
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004613 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 990
# [LightGBM] [Info] Number of data points in the train set: 7813, number of used features: 42
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.471906 -> initscore=-0.112495
# [LightGBM] [Info] Start training from score -0.112495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
# [I 2024-09-19 12:25:31,700] Trial 49 finished with value: 0.849507315616602 and parameters: {'num_leaves': 207, 'learning_rate': 0.007893600781646309, 'n_estimators': 706, 'max_depth': 6}. Best is trial 27 with value: 0.8596595998805614.
# {'num_leaves': 133, 'learning_rate': 0.025484673694089244, 'n_estimators': 460, 'max_depth': 7}

# %% [markdown]
# - Trial 49의 결과:
#
# 성능 값: 0.849507315616602
# 하이퍼파라미터:
# num_leaves: 207
# learning_rate: 0.007893600781646309
# n_estimators: 706
# max_depth: 6
#
# - 최적의 트라이얼 (Best):
#
# 성능 값: 0.8596595998805614 (최고 성능)
# 하이퍼파라미터:
# num_leaves: 133
# learning_rate: 0.025484673694089244
# n_estimators: 460

# %%
import optuna.visualization as vis

# 하이퍼파라미터 중요도 시각화
vis.plot_param_importances(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import optuna.visualization as vis

# 최적화 과정에서의 성능 변화 시각화
vis.plot_optimization_history(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
